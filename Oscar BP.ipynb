# %%
import re
import pandas as pd
import numpy as np
from rapidfuzz import process, fuzz
import requests
from bs4 import BeautifulSoup as bs

from get_imdb import get_imdb
from get_meta import get_meta
from get_rt import get_rt
from get_tn import get_tn
from format_title import format_title

pd.set_option('display.max_rows', None)

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36',
    'Referer': 'https://www.google.com/',
    'Accept-Language': 'en-US,en;q=0.9',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
    'DNT': '1',  # Do Not Track
    'Connection': 'keep-alive',
    'Upgrade-Insecure-Requests': '1'
          }

year = list(range(1962, 2026))

# %% [markdown]
# # I. IMDB

# %%
imdb = []

for y in year:
    
    # link to get list of best picture from each oscar year
    url = f'https://www.imdb.com/event/ev0000003/{y}/1/'
    response = requests.get(url, headers=headers)
    soup = bs(response.text, 'html.parser')
    
    bp = soup.find('a', href='#oscar_best_motion_picture_of_the_year')
    if not bp:
        bp = soup.find('a', href='#oscar_best_picture')

    section = bp.find_next('section')
    films = section.find_all('a', class_='ipc-title-link-wrapper')

    for f in films:
        
        # film title
        title = f.text.strip()
        
        # imdb id
        imdb_id = f['href'].split('/')[2]
        
        # winner/nominee
        parent_div = f.find_parent('div')
        prev = parent_div.find_previous_sibling()
        result = 'Winner' if prev else 'Nominated'
        
        # film details from imdb website
        release_year, rated, budget, language, imdb_rating, imdb_votes = get_imdb(imdb_id=imdb_id, headers=headers)

        imdb.append({
            'oscar year': y,
            'title': title,
            'imdb id': imdb_id,
            'result': result,
            'release year': release_year,
            'rated': rated,
            'budget': budget,
            'language': language,
            'imdb rating': imdb_rating,
            'imdb votes': imdb_votes
        })

# %% [markdown]
# # II. Metacritic

# %%
meta = []

for film in imdb:
    
    # film title
    title = film['title']
    
    # metacritic id
    meta_id = format_title(title, style='meta', sep='-')  # apply function to transform title into id
    
    url = f'https://www.metacritic.com/movie/{meta_id}'  # link to the metacritic page of a film
    
    # film details from the metacritic website
    metascore, meta_votes, release_year = get_meta(url=url, headers=headers)
    
    meta.append({
        'title': title,
        'release year': release_year,
        'meta id': meta_id,
        'metascore': metascore,
        'meta votes': meta_votes
    })

# %% [markdown]
# ## Correction

# %%
mm = []

for i, (film_imdb, film_meta) in enumerate(zip(imdb, meta)):
    imdb_year = film_imdb['release year']
    meta_year = film_meta['release year']
    
    if imdb_year != meta_year:
        mm.append({
            'index': i,
            'title': film_imdb['title'],
            'imdb_year': imdb_year,
            'meta_year': meta_year,
            'meta_id': film_meta['meta id']
        })

# %%
print(f'{len(mm)} films need to be checked')
pd.DataFrame(mm)
# Out:
# 59 films need to be checked
#     index                              title imdb_year meta_year  \
# 0       1                              Fanny      1961      2014
# 1       5                 Lawrence of Arabia      1962
# 2       8               Mutiny on the Bounty      1962      1935
# 3      13               How the West Was Won      1962      1963
# 4      16                             Becket      1964
# 5      19                    Zorba the Greek      1964
# 6      21                            Darling      1965      2016
# 7      23                      Ship of Fools      1965
# 8      24                  A Thousand Clowns      1965
# 9      26                              Alfie      1966      2004
# 10     28                   The Sand Pebbles      1966
# 11     32                    Doctor Dolittle      1967
# 12     35                            Oliver!      1968
# 55                              tar
# 56   all-quiet-on-the-western-front
# 57                          maestro
# 58                    im-still-here

# %%
keep_list = {13, 99, 100, 101, 105, 
             116, 117, 129, 133, 138, 
             187, 189, 220, 240, 343, 345
            }

mm = [film for film in mm if film['index'] not in keep_list]

# %%
# Recheck mm items with new meta_id format (with imdb year appended)
for film in mm:
    i = film['index']
    meta_id = f"{film['meta_id']}-{film['imdb_year']}"
    url = f"https://www.metacritic.com/movie/{meta_id}"

    metascore, meta_votes, release_year = get_meta(url=url, headers=headers)

    # Update meta list without overwriting 'oscar year' and 'title'
    meta[i]['release year'] = release_year
    meta[i]['meta id'] = meta_id
    meta[i]['metascore'] = metascore
    meta[i]['meta votes'] = meta_votes

    # Update mm entry
    film['meta_id'] = meta_id
    film['meta_year'] = release_year

# %%
print(f'{len(mm)} films need to be checked')
pd.DataFrame(mm)
# Out:
# 43 films need to be checked
#     index                              title imdb_year meta_year  \
# 0       1                              Fanny      1961
# 1       5                 Lawrence of Arabia      1962
# 2       8               Mutiny on the Bounty      1962      1962
# 3      16                             Becket      1964
# 4      19                    Zorba the Greek      1964
# 5      21                            Darling      1965
# 6      23                      Ship of Fools      1965
# 7      24                  A Thousand Clowns      1965
# 8      26                              Alfie      1966      1966
# 9      28                   The Sand Pebbles      1966
# 10     32                    Doctor Dolittle      1967      1967
# 11     35                            Oliver!      1968
# 12     37                 The Lion in Winter      1968
# 13     39                   Romeo and Juliet      1968      1968
# 14     41          Anne of the Thousand Days      1969
# 15     43                      Hello, Dolly!      1969
# 16     44                                  Z      1969      1969
# 17     50              The French Connection      1971      1971
# 18     58                      The Emigrants      1971
# 19     62                   Cries & Whispers      1972
# 20     63                       The Exorcist      1973      1973
# 21     64                   A Touch of Class      1973
# 22     79                        Taxi Driver      1976      1976
# 23     80                         Annie Hall      1977      1977
# 24     82                              Julia      1977      1977
# 25     86                        Coming Home      1978      1978
# 26    112                        The Dresser      1983
# 27    151               Beauty and the Beast      1991      1991
# 28    173                        The Postman      1994
# 29    204                      Moulin Rouge!      2001
# 30    246                           Precious      2009
# 31    263  Extremely Loud & Incredibly Close      2011
# 32    296                       The Revenant      2015      2015
# 33    297                               Room      2015      2015
# 34    303                          Moonlight      2016      2016
# 35    328                               Vice      2018      2018
# 36    335                       Little Women      2019      2019
# 37    346                               CODA      2021      2021
# 38    348                    West Side Story      2021
# 39    361                                Tár      2022      2022
# 40    365     All Quiet on the Western Front      2022      2022
# 41    373                            Maestro      2023      2023
# 42    385                     I'm Still Here      2024      2025
#
#                                  meta_id
# 0                             fanny-1961
# 1                lawrence-of-arabia-1962
# 2              mutiny-on-the-bounty-1962
# 3                            becket-1964
# 4                   zorba-the-greek-1964
# 5                           darling-1965
# 6                     ship-of-fools-1965
# 7                 a-thousand-clowns-1965
# 8                             alfie-1966
# 9                  the-sand-pebbles-1966
# 10                  doctor-dolittle-1967
# 11                           oliver-1968
# 12               the-lion-in-winter-1968
# 13                 romeo-and-juliet-1968
# 14        anne-of-the-thousand-days-1969
# 15                      hello-dolly-1969
# 16                                z-1969
# 17            the-french-connection-1971
# 18                    the-emigrants-1971
# 19                   cries-whispers-1972
# 20                     the-exorcist-1973
# 21                 a-touch-of-class-1973
# 22                      taxi-driver-1976
# 23                       annie-hall-1977
# 24                            julia-1977
# 25                      coming-home-1978
# 26                      the-dresser-1983
# 27             beauty-and-the-beast-1991
# 28                      the-postman-1994
# 29                     moulin-rouge-2001
# 30                         precious-2009
# 31  extremely-loud-incredibly-close-2011
# 32                     the-revenant-2015
# 33                             room-2015
# 34                        moonlight-2016
# 35                             vice-2018
# 36                     little-women-2019
# 37                             coda-2021
# 38                  west-side-story-2021
# 39                              tar-2022
# 40   all-quiet-on-the-western-front-2022
# 41                          maestro-2023
# 42                    im-still-here-2024

# %%
mm = [film for film in mm if film['imdb_year'] != film['meta_year']]

# %%
print(f'{len(mm)} films need to be checked')
pd.DataFrame(mm)
# Out:
# 22 films need to be checked
#     index                              title imdb_year meta_year  \
# 0       1                              Fanny      1961
# 1       5                 Lawrence of Arabia      1962
# 2      16                             Becket      1964
# 3      19                    Zorba the Greek      1964
# 4      21                            Darling      1965
# 5      23                      Ship of Fools      1965
# 6      24                  A Thousand Clowns      1965
# 7      28                   The Sand Pebbles      1966
# 8      35                            Oliver!      1968
# 9      37                 The Lion in Winter      1968
# 10     41          Anne of the Thousand Days      1969
# 11     43                      Hello, Dolly!      1969
# 12     58                      The Emigrants      1971
# 13     62                   Cries & Whispers      1972
# 14     64                   A Touch of Class      1973
# 15    112                        The Dresser      1983
# 16    173                        The Postman      1994
# 17    204                      Moulin Rouge!      2001
# 18    246                           Precious      2009
# 19    263  Extremely Loud & Incredibly Close      2011
# 20    348                    West Side Story      2021
# 21    385                     I'm Still Here      2024      2025
#
#                                  meta_id
# 0                             fanny-1961
# 1                lawrence-of-arabia-1962
# 2                            becket-1964
# 3                   zorba-the-greek-1964
# 4                           darling-1965
# 5                     ship-of-fools-1965
# 6                 a-thousand-clowns-1965
# 7                  the-sand-pebbles-1966
# 8                            oliver-1968
# 9                the-lion-in-winter-1968
# 10        anne-of-the-thousand-days-1969
# 11                      hello-dolly-1969
# 12                    the-emigrants-1971
# 13                   cries-whispers-1972
# 14                 a-touch-of-class-1973
# 15                      the-dresser-1983
# 16                      the-postman-1994
# 17                     moulin-rouge-2001
# 18                         precious-2009
# 19  extremely-loud-incredibly-close-2011
# 20                  west-side-story-2021
# 21                    im-still-here-2024

# %%
update = {
    5: 'lawrence-of-arabia-re-release',
    16: 'becket-re-release',
    32: 'doctor-dolittle-1967',
    35: 'oliver!',
    43: 'hello-dolly!',
    173: 'il-postino-the-postman',
    178: 'secrets-lies',
    204: 'moulin-rouge!',
    246: 'precious-based-on-the-novel-push-by-sapphire',
    263: 'extremely-loud-and-incredibly-close',
    348: 'west-side-story-2020'
}

# %%
for i, meta_id in update.items():
    url = f"https://www.metacritic.com/movie/{meta_id}"
    
    # Re-scrape the Metacritic data using the new meta_id
    metascore, meta_votes, release_year = get_meta(url=url, headers=headers)
    
    # Update the meta list at index i
    meta[i]['release year'] = release_year
    meta[i]['meta id'] = meta_id
    meta[i]['metascore'] = metascore
    meta[i]['meta votes'] = meta_votes

# %%
for film in meta:
    if film['release year'] == '':
        film['meta id'] = ''

# %% [markdown]
# # III. Rotten Tomatoes

# %%
rt = []

for film in imdb:
    
    # film title
    title = film['title']
    
    # rt id (to get link the the film)
    rt_id = format_title(title, style='meta', sep='_')  # apply function to transform title into id
    
    url = f'https://www.rottentomatoes.com/m/{rt_id}'    
    release_year, rt_score, rt_votes, audience_score, audience_votes = get_rt(url=url, headers=headers)
    
    rt.append({
        'title': title,
        'release year': release_year,
        'rt id': rt_id,
        'rt score': rt_score,
        'rt votes': rt_votes,
        'audience score': audience_score,
        'audience votes': audience_votes
    })

# %% [markdown]
# ## Correction

# %%
mm2 = []

for i, (film_imdb, film_rt) in enumerate(zip(imdb, rt)):
    imdb_year = film_imdb['release year']
    rt_year = film_rt['release year']
    
    if imdb_year != rt_year:
        mm2.append({
            'index': i,
            'title': film_imdb['title'],
            'imdb_year': imdb_year,
            'rt_year': rt_year,
            'rt_id': film_rt['rt id']
        })

# %%
print(f'{len(mm2)} films need to be checked')
pd.DataFrame(mm2)
# Out:
# 158 films need to be checked
#      index                                              title imdb_year  \
# 0        1                                              Fanny      1961
# 1        2                               The Guns of Navarone      1961
# 2        3                                        The Hustler      1961
# 3        6                                    The Longest Day      1962
# 4        8                               Mutiny on the Bounty      1962
# 5       12                                          Cleopatra      1963
# 6       14                                Lilies of the Field      1963
# 7       17  Dr. Strangelove or: How I Learned to Stop Worr...      1964
# 8       20                                 The Sound of Music      1965
# 9       21                                            Darling      1965
# 10      24                                  A Thousand Clowns      1965
# 11      25                              A Man for All Seasons      1966
# 12      26                                              Alfie      1966
# 13      27    The Russians Are Coming the Russians Are Coming      1966
# 14      28                                   The Sand Pebbles      1966
# 15      33                                       The Graduate      1967
# 16      37                                 The Lion in Winter      1968
# 17      39                                   Romeo and Juliet      1968
# 18      42                 Butch Cassidy and the Sundance Kid      1969
# 19      51                                 A Clockwork Orange      1971
# 20      53                              The Last Picture Show      1971
# 21      54                             Nicholas and Alexandra      1971
# 22      58                                      The Emigrants      1971
# 23      60                                          The Sting      1973
# 24      62                                   Cries & Whispers      1972
# 25      64                                   A Touch of Class      1973
# 26      65                              The Godfather Part II      1974
# 27      68                                              Lenny      1974
# 28      69                               The Towering Inferno      1974
# 29      75                                              Rocky      1976
# 30      82                                              Julia      1977
# 31      83                 Star Wars: Episode IV - A New Hope      1977
# 32      84                                  The Turning Point      1977
# 33      89                                 An Unmarried Woman      1978
# 34      97                                   The Elephant Man      1980
# 35     101                                      Atlantic City      1980
# 36     102                                     On Golden Pond      1981
# 37     106                         E.T. the Extra-Terrestrial      1982
# 38     107                                            Missing      1982
# 39     109                                        The Verdict      1982
# 40     111                                      The Big Chill      1983
# 41     112                                        The Dresser      1983
# 42     117                                 A Passage to India      1984
# 43     121                                   The Color Purple      1985
# 44     124                                            Witness      1985
# 129    315                                            Dunkirk      2017
# 130    318                                           The Post      2017
# 131    320                                     Phantom Thread      2017
# 132    323                                      Black Panther      2018
# 133    328                                               Vice      2018
# 134    329                                           Parasite      2019
# 135    331                                               1917      2019
# 136    332                                     Marriage Story      2019
# 137    333                                              Joker      2019
# 138    335                                       Little Women      2019
# 139    338                                          Nomadland      2020
# 140    342                                             Minari      2020
# 141    343                                     Sound of Metal      2019
# 142    345                                         The Father      2020
# 143    346                                               CODA      2021
# 144    348                                    West Side Story      2021
# 145    350                                     Dune: Part One      2021
# 146    354                                      Don't Look Up      2021
# 147    355                                    Nightmare Alley      2021
# 148    361                                                Tár      2022
# 149    363                                      Women Talking      2022
# 150    365                     All Quiet on the Western Front      2022
# 151    366                                        Oppenheimer      2023
# 152    373                                            Maestro      2023
# 153    375                                   American Fiction      2023
# 154    377                                             Wicked      2024
# 155    380                                      The Brutalist      2024
# 156    383                                        Nickel Boys      2024
# 157    385                                     I'm Still Here      2024
#
#     rt_year                                              rt_id
# 0      2015                                              fanny
# 1                                         the_guns_of_navarone
# 2                                                  the_hustler
# 3                                              the_longest_day
# 4      1935                               mutiny_on_the_bounty
# 5      2004                                          cleopatra
# 6                                          lilies_of_the_field
# 7            dr_strangelove_or_how_i_learned_to_stop_worryi...
# 8                                           the_sound_of_music
# 9                                                      darling
# 10                                           a_thousand_clowns
# 11     2012                              a_man_for_all_seasons
# 12     2004                                              alfie
# 13             the_russians_are_coming_the_russians_are_coming
# 14                                            the_sand_pebbles
# 15                                                the_graduate
# 16                                          the_lion_in_winter
# 17                                            romeo_and_juliet
# 18                          butch_cassidy_and_the_sundance_kid
# 19                                          a_clockwork_orange
# 20                                       the_last_picture_show
# 21                                      nicholas_and_alexandra
# 22     1972                                      the_emigrants
# 23                                                   the_sting
# 24                                              cries_whispers
# 25                                            a_touch_of_class
# 26                                       the_godfather_part_ii
# 27     1975                                              lenny
# 28                                        the_towering_inferno
# 29                                                       rocky
# 30     2020                                              julia
# 31                           star_wars_episode_iv_-_a_new_hope
# 32                                           the_turning_point
# 33                                          an_unmarried_woman
# 34                                            the_elephant_man
# 35     1981                                      atlantic_city
# 36     1982                                     on_golden_pond
# 37                                    et_the_extra-terrestrial
# 38                                                     missing
# 39                                                 the_verdict
# 40                                               the_big_chill
# 41     2016                                        the_dresser
# 42     1985                                 a_passage_to_india
# 43     2023                                   the_color_purple
# 44                                                     witness
# 45                                                 the_mission
# 46                                          a_room_with_a_view
# 47                                            the_last_emperor
# 48                                            fatal_attraction
# 49                                      the_accidental_tourist
# 50                                          dangerous_liaisons
# 51     1989                                mississippi_burning
# 52                                                  awakenings
# 53                                                       ghost
# 54                                      the_godfather_part_iii
# 55     1947                               beauty_and_the_beast
# 56                                                         jfk
# 57                                         the_prince_of_tides
# 58                                                  unforgiven
# 59                                             the_crying_game
# 60                                              a_few_good_men
# 61                                            scent_of_a_woman
# 62                                                the_fugitive
# 63                                                   the_piano
# 64                                      the_remains_of_the_day
# 65                                                  braveheart
# 66                                                        babe
# 67     2008                                        the_postman
# 68                                       sense_and_sensibility
# 69                                         the_english_patient
# 70                                                secrets_lies
# 71                                              the_full_monty
# 72     1998                                  good_will_hunting
# 73                                                   elizabeth
# 74                                           life_is_beautiful
# 75                                           the_thin_red_line
# 76                                       the_cider_house_rules
# 77                                                 the_insider
# 78                                             the_sixth_sense
# 79     2001                                           chocolat
# 80                                                     traffic
# 81     2002                                   a_beautiful_mind
# 82     2016                                       moulin_rouge
# 83     2003                                            chicago
# 84                                                   the_hours
# 85     2017                                        the_pianist
# 86                                                 the_aviator
# 87                                                       crash
# 88                                                      capote
# 89     2006                                             munich
# 90     2007                              letters_from_iwo_jima
# 91     2008                                there_will_be_blood
# 92     2009                                slumdog_millionaire
# 93                         the_curious_case_of_benjamin_button
# 94     2016                                         the_reader
# 95     2009                                    the_hurt_locker
# 96     1940                                      up_in_the_air
# 97     2011                                   the_kings_speech
# 98     2011                                          127_hours
# 99     1942                                         black_swan
# 100    1969                                          true_grit
# 101                                               winters_bone
# 102                                           the_tree_of_life
# 103                                            the_descendants
# 104                            extremely_loud_incredibly_close
# 105                                                       argo
# 106                                                      amour
# 107                                             les_miserables
# 108                                                    lincoln
# 109    2013                                   zero_dark_thirty
# 110                                    the_wolf_of_wall_street
# 111                                                    gravity
# 112    2014                                                her
# 113              birdman_or_the_unexpected_virtue_of_ignorance
# 114    2015                                    american_sniper
# 115    2015                                              selma
# 116                                   the_theory_of_everything
# 117                                                   whiplash
# 118                                                  spotlight
# 119                                               the_revenant
# 120                                                       room
# 121                                                  moonlight
# 122                                                    arrival
# 123                                                     fences
# 124    2017                                     hidden_figures
# 125                                                       lion
# 126                                         the_shape_of_water
# 127    2018                               call_me_by_your_name
# 128                                               darkest_hour
# 129    2016                                            dunkirk
# 130    2018                                           the_post
# 131    2018                                     phantom_thread
# 132                                              black_panther
# 133                                                       vice
# 134                                                   parasite
# 135                                                       1917
# 136                                             marriage_story
# 137                                                      joker
# 138    1958                                       little_women
# 139    2021                                          nomadland
# 140    2021                                             minari
# 141    2020                                     sound_of_metal
# 142                                                 the_father
# 143                                                       coda
# 144    1961                                    west_side_story
# 145                                              dune_part_one
# 146                                               dont_look_up
# 147    1947                                    nightmare_alley
# 148    2003                                                tar
# 149    2023                                      women_talking
# 150    1930                     all_quiet_on_the_western_front
# 151                                                oppenheimer
# 152                                                    maestro
# 153    2024                                   american_fiction
# 154                                                     wicked
# 155    2025                                      the_brutalist
# 156    2025                                        nickel_boys
# 157                                              im_still_here

# %%
keep_list = {
    58, 68, 101, 102, 117, 138, 183, 196, 
    200, 205, 224, 227, 234, 235, 240, 250, 
    251, 277, 286, 288, 292, 308, 313, 318, 
    320, 338, 342, 343, 363, 375, 380, 383
            }

mm2 = [film for film in mm2 if film['index'] not in keep_list]

# %%
# Recheck mm2 items with conditional logic for article prefix and imdb year fallback
for film in mm2:
    i = film['index']
    rt_id = film['rt_id']
    
    # Case 1: rt_id starts with "the_", "a_", "an_"
    if rt_id.startswith(("the_", "a_", "an_")):
        l = rt_id.find('_') + 1
        temp_id = rt_id[l:]  # Remove article
        url = f'https://www.rottentomatoes.com/m/{temp_id}'
        release_year, rt_score, rt_votes, audience_score, audience_votes = get_rt(url=url, headers=headers)
        
        if release_year:  # Success
            rt[i]['rt id'] = temp_id
        else:
            # Fallback: add IMDb year to original rt_id
            temp_id = f"{rt_id}_{film['imdb_year']}"
            url = f'https://www.rottentomatoes.com/m/{temp_id}'
            release_year, rt_score, rt_votes, audience_score, audience_votes = get_rt(url=url, headers=headers)
            rt[i]['rt id'] = temp_id
    
    # Case 2: rt_id does NOT start with "the_"
    else:
        temp_id = f"{rt_id}_{film['imdb_year']}"
        url = f'https://www.rottentomatoes.com/m/{temp_id}'
        release_year, rt_score, rt_votes, audience_score, audience_votes = get_rt(url=url, headers=headers)
        rt[i]['rt id'] = temp_id

    # Update rt list
    rt[i]['release year'] = release_year
    rt[i]['rt score'] = rt_score
    rt[i]['rt votes'] = rt_votes
    rt[i]['audience score'] = audience_score
    rt[i]['audience votes'] = audience_votes

    # Update mm2 entry
    film['rt_id'] = rt[i]['rt id']
    film['rt_year'] = release_year

# %%
print(f'{len(mm2)} films need to be checked')
pd.DataFrame(mm2)
# Out:
# 126 films need to be checked
#      index                                              title imdb_year  \
# 0        1                                              Fanny      1961
# 1        2                               The Guns of Navarone      1961
# 2        3                                        The Hustler      1961
# 3        6                                    The Longest Day      1962
# 4        8                               Mutiny on the Bounty      1962
# 5       12                                          Cleopatra      1963
# 6       14                                Lilies of the Field      1963
# 7       17  Dr. Strangelove or: How I Learned to Stop Worr...      1964
# 8       20                                 The Sound of Music      1965
# 9       21                                            Darling      1965
# 10      24                                  A Thousand Clowns      1965
# 11      25                              A Man for All Seasons      1966
# 12      26                                              Alfie      1966
# 13      27    The Russians Are Coming the Russians Are Coming      1966
# 14      28                                   The Sand Pebbles      1966
# 15      33                                       The Graduate      1967
# 16      37                                 The Lion in Winter      1968
# 17      39                                   Romeo and Juliet      1968
# 18      42                 Butch Cassidy and the Sundance Kid      1969
# 19      51                                 A Clockwork Orange      1971
# 20      53                              The Last Picture Show      1971
# 21      54                             Nicholas and Alexandra      1971
# 22      60                                          The Sting      1973
# 23      62                                   Cries & Whispers      1972
# 24      64                                   A Touch of Class      1973
# 25      65                              The Godfather Part II      1974
# 26      69                               The Towering Inferno      1974
# 27      75                                              Rocky      1976
# 28      82                                              Julia      1977
# 29      83                 Star Wars: Episode IV - A New Hope      1977
# 30      84                                  The Turning Point      1977
# 31      89                                 An Unmarried Woman      1978
# 32      97                                   The Elephant Man      1980
# 33     106                         E.T. the Extra-Terrestrial      1982
# 34     107                                            Missing      1982
# 35     109                                        The Verdict      1982
# 36     111                                      The Big Chill      1983
# 37     112                                        The Dresser      1983
# 38     121                                   The Color Purple      1985
# 39     124                                            Witness      1985
# 40     128                                        The Mission      1986
# 41     129                                 A Room with a View      1985
# 42     130                                   The Last Emperor      1987
# 43     132                                   Fatal Attraction      1987
# 4                                    mutiny_on_the_bounty_1962
# 5                                               cleopatra_1963
# 6                                     lilies_of_the_field_1963
# 7            dr_strangelove_or_how_i_learned_to_stop_worryi...
# 8      1965                                     sound_of_music
# 9                                                 darling_1965
# 10     1965                                    thousand_clowns
# 11                                  a_man_for_all_seasons_1966
# 12                                                  alfie_1966
# 13     1966        russians_are_coming_the_russians_are_coming
# 14     1966                                       sand_pebbles
# 15     1967                                           graduate
# 16                                     the_lion_in_winter_1968
# 17     1968                              romeo_and_juliet_1968
# 18                     butch_cassidy_and_the_sundance_kid_1969
# 19     1971                                   clockwork_orange
# 20     1971                                  last_picture_show
# 21                                 nicholas_and_alexandra_1971
# 22     2024                                              sting
# 23                                         cries_whispers_1972
# 24     1973                                     touch_of_class
# 25     1974                                  godfather_part_ii
# 26     1974                                   towering_inferno
# 27                                                  rocky_1976
# 28                                                  julia_1977
# 29                      star_wars_episode_iv_-_a_new_hope_1977
# 30     2009                                      turning_point
# 31     1978                                    unmarried_woman
# 32     2017                                       elephant_man
# 33                               et_the_extra-terrestrial_1982
# 34                                                missing_1982
# 35     1982                                            verdict
# 36     1983                                          big_chill
# 37     1983                                            dresser
# 38     1985                                       color_purple
# 39                                                witness_1985
# 40     1986                                   the_mission_1986
# 41     1986                            a_room_with_a_view_1985
# 42     1987                                       last_emperor
# 43                                       fatal_attraction_1987
# 44     1989                                 accidental_tourist
# 45     1988                            dangerous_liaisons_1988
# 46                                             awakenings_1990
# 47                                                  ghost_1990
# 48     1990                                 godfather_part_iii
# 49     1991                          beauty_and_the_beast_1991
# 50     1991                                           jfk_1991
# 51     1991                                    prince_of_tides
# 52     1992                                    unforgiven_1992
# 53     1992                                        crying_game
# 54     1992                                       few_good_men
# 55                                       scent_of_a_woman_1992
# 56     1993                                  the_fugitive_1993
# 57     1993                                              piano
# 58     1993                                 remains_of_the_day
# 59                                             braveheart_1995
# 60                                                   babe_1995
# 61     2008                                            postman
# 62                                  sense_and_sensibility_1995
# 63     1996                                    english_patient
# 64                                           secrets_lies_1996
# 65     1997                                         full_monty
# 66                                              elizabeth_1998
# 67                                      life_is_beautiful_1997
# 68                                      the_thin_red_line_1998
# 69     1999                                  cider_house_rules
# 70     1999                                            insider
# 71     1999                                        sixth_sense
# 72                                                traffic_2000
# 73     2001                                  moulin_rouge_2001
# 74     2002                                              hours
# 75     2002                                            pianist
# 76     2004                                            aviator
# 77                                                  crash_2004
# 78                                                 capote_2005
# 79     2008                    curious_case_of_benjamin_button
# 80     2009                                             reader
# 81     2009                                 up_in_the_air_2009
# 82     2010                                    black_swan_2010
# 83     2010                                     true_grit_2010
# 84                                           winters_bone_2010
# 85     2011                              the_tree_of_life_2011
# 86     2017                                        descendants
# 87                        extremely_loud_incredibly_close_2011
# 88     2012                                          argo_2012
# 89     2012                                         amour_2012
# 90     2012                                les_miserables_2012
# 91     2012                                       lincoln_2012
# 92     2013                       the_wolf_of_wall_street_2013
# 93     2013                                       gravity_2013
# 94           birdman_or_the_unexpected_virtue_of_ignorance_...
# 95     2014                      the_theory_of_everything_2014
# 96     2014                                      whiplash_2014
# 97     2015                                     spotlight_2015
# 98     2016                                           revenant
# 99     2016                                          room_2015
# 100    2016                                     moonlight_2016
# 101    2016                                       arrival_2016
# 102    2016                                        fences_2016
# 103    2016                                          lion_2016
# 104    2017                            the_shape_of_water_2017
# 105    2017                                  darkest_hour_2017
# 106    2017                                       dunkirk_2017
# 107    2018                                 black_panther_2018
# 108    2018                                          vice_2018
# 109    2019                                      parasite_2019
# 110    2020                                          1917_2019
# 111    2019                                marriage_story_2019
# 112    2019                                         joker_2019
# 113    2019                                  little_women_2019
# 114    2021                                    the_father_2020
# 115    2021                                          coda_2021
# 116    2021                               west_side_story_2021
# 117                                         dune_part_one_2021
# 118    2021                                  dont_look_up_2021
# 119    2021                               nightmare_alley_2021
# 120    2022                                           tar_2022
# 121    2022                all_quiet_on_the_western_front_2022
# 122    2023                                   oppenheimer_2023
# 123    2023                                       maestro_2023
# 124    2024                                        wicked_2024
# 125    2025                                 im_still_here_2024

# %%
mm2 = [film for film in mm2 if film['imdb_year'] != film['rt_year']]

# %%
print(f'{len(mm2)} films need to be checked')
pd.DataFrame(mm2)
# Out:
# 49 films need to be checked
#     index                                              title imdb_year  \
# 0       1                                              Fanny      1961
# 1       8                               Mutiny on the Bounty      1962
# 2      12                                          Cleopatra      1963
# 3      14                                Lilies of the Field      1963
# 4      17  Dr. Strangelove or: How I Learned to Stop Worr...      1964
# 5      21                                            Darling      1965
# 6      25                              A Man for All Seasons      1966
# 7      26                                              Alfie      1966
# 8      37                                 The Lion in Winter      1968
# 9      42                 Butch Cassidy and the Sundance Kid      1969
# 10     54                             Nicholas and Alexandra      1971
# 11     60                                          The Sting      1973
# 12     62                                   Cries & Whispers      1972
# 13     75                                              Rocky      1976
# 14     82                                              Julia      1977
# 15     83                 Star Wars: Episode IV - A New Hope      1977
# 16     84                                  The Turning Point      1977
# 17     97                                   The Elephant Man      1980
# 18    106                         E.T. the Extra-Terrestrial      1982
# 19    107                                            Missing      1982
# 20    124                                            Witness      1985
# 21    129                                 A Room with a View      1985
# 22    132                                   Fatal Attraction      1987
# 23    136                             The Accidental Tourist      1988
# 24    146                                         Awakenings      1990
# 25    147                                              Ghost      1990
# 26    159                                   Scent of a Woman      1992
# 27    170                                         Braveheart      1995
# 28    172                                               Babe      1995
# 29    173                                        The Postman      1994
# 30    174                              Sense and Sensibility      1995
# 31    178                                     Secrets & Lies      1996
# 32    186                                          Elizabeth      1998
# 33    187                                  Life Is Beautiful      1997
# 34    189                                  The Thin Red Line      1998
# 35    199                                            Traffic      2000
# 36    220                                              Crash      2004
# 37    222                                             Capote      2005
# 38    239                                         The Reader      2008
# 39    259                                      Winter's Bone      2010
# 40    262                                    The Descendants      2011
# 41    263                  Extremely Loud & Incredibly Close      2011
# 42    287    Birdman or (The Unexpected Virtue of Ignorance)      2014
# 43    296                                       The Revenant      2015
# 44    297                                               Room      2015
# 45    331                                               1917      2019
# 46    345                                         The Father      2020
# 47    350                                     Dune: Part One      2021
# 48    385                                     I'm Still Here      2024
#
#    rt_year                                              rt_id
# 0                                                  fanny_1961
# 1                                   mutiny_on_the_bounty_1962
# 2                                              cleopatra_1963
# 3                                    lilies_of_the_field_1963
# 4           dr_strangelove_or_how_i_learned_to_stop_worryi...
# 5                                                darling_1965
# 6                                  a_man_for_all_seasons_1966
# 7                                                  alfie_1966
# 8                                     the_lion_in_winter_1968
# 9                     butch_cassidy_and_the_sundance_kid_1969
# 10                                nicholas_and_alexandra_1971
# 11    2024                                              sting
# 12                                        cries_whispers_1972
# 13                                                 rocky_1976
# 14                                                 julia_1977
# 15                     star_wars_episode_iv_-_a_new_hope_1977
# 16    2009                                      turning_point
# 17    2017                                       elephant_man
# 18                              et_the_extra-terrestrial_1982
# 19                                               missing_1982
# 20                                               witness_1985
# 21    1986                            a_room_with_a_view_1985
# 22                                      fatal_attraction_1987
# 23    1989                                 accidental_tourist
# 24                                            awakenings_1990
# 25                                                 ghost_1990
# 26                                      scent_of_a_woman_1992
# 27                                            braveheart_1995
# 28                                                  babe_1995
# 29    2008                                            postman
# 30                                 sense_and_sensibility_1995
# 31                                          secrets_lies_1996
# 32                                             elizabeth_1998
# 33                                     life_is_beautiful_1997
# 34                                     the_thin_red_line_1998
# 35                                               traffic_2000
# 36                                                 crash_2004
# 37                                                capote_2005
# 38    2009                                             reader
# 39                                          winters_bone_2010
# 40    2017                                        descendants
# 41                       extremely_loud_incredibly_close_2011
# 42          birdman_or_the_unexpected_virtue_of_ignorance_...
# 43    2016                                           revenant
# 44    2016                                          room_2015
# 45    2020                                          1917_2019
# 46    2021                                    the_father_2020
# 47                                         dune_part_one_2021
# 48    2025                                 im_still_here_2024

# %%
update = {
    1: '1007078-fanny',
    8: '1014482-mutiny_on_the_bounty',
    12: '1004330-cleopatra',
    14: '1012370-lilies_of_the_field',
    17: 'dr_strangelove',
    21: '1005279-darling',
    25: '1013162-man_for_all_seasons',
    26: '1000581-alfie',
    37: '1012386-lion_in_winter',
    42: '1003318-butch_cassidy_and_the_sundance_kid',
    54: '1014986-nicholas_and_alexandra',
    60: '1020130-sting',
    62: 'cries_and_whispers',
    75: '1017776-rocky',
    82: 'julia1977',
    83: 'star_wars_episode_iv_a_new_hope',
    84: '1022131-turning_point',
    97: '1006527-elephant_man',
    106: 'et_the_extraterrestrial',
    107: '1014007-missing',
    124: '1023854-witness',
    132: '1007141-fatal_attraction',
    146: '1032970-awakenings',
    147: '1031086-ghost',
    159: '1042193-scent_of_a_woman',
    170: '1065684-braveheart',
    172: '1065598-babe',
    173: 'il_postino_the_postman',
    174: '1068832-sense_and_sensibility',
    178: 'secrets_and_lies',
    186: '1084153-elizabeth',
    187: '1084398-life_is_beautiful',
    189: '1084146-thin_red_line',
    199: '1103281-traffic',
    220: '1144992-crash',
    222: '1151898-capote',
    259: '10012136-winters_bone',
    262: 'the_descendants_2011',
    263: 'extremely_loud_and_incredibly_close',
    287: 'birdman_2014',
    296: 'the_revenant_2015',
    350: 'dune_2021'       
}

# %%
for i, rt_id in update.items():
    url = f'https://www.rottentomatoes.com/m/{rt_id}'
    
    # Re-scrape the RT data using the new rt_id
    release_year, rt_score, rt_votes, audience_score, audience_votes = get_rt(url=url, headers=headers)
    
    # Update the rt list at index i
    rt[i]['release year'] = release_year
    rt[i]['rt id'] = rt_id
    rt[i]['rt score'] = rt_score
    rt[i]['rt votes'] = rt_votes
    rt[i]['audience score'] = audience_score
    rt[i]['audience votes'] = audience_votes

# %% [markdown]
# # IV. The Numbers

# %%
tn = []

for y in year:
    oscar_year = y

    url = f'https://www.the-numbers.com/movies/keyword/{y}-Oscars-Best-Picture-Nominee'
    response = requests.get(url, headers=headers)
    soup = bs(response.text, 'html.parser')
    table = soup.find('table', id='keyword_movies')

    if table:
        rows = table.find_all('tr')[1:]  # Skip header row

        for row in rows:
            cols = row.find_all('td')
            a_tag = cols[1].find('a')
            
            # title
            title = a_tag.text.strip()
            
            # id
            tn_id = a_tag['href'].split('/movie/')[-1].split('#')[0]

            tn.append({
                'oscar year': oscar_year,
                'title': title,
                'tn id': tn_id
            })

# %%
extra_movies = [{
        'title': film['title'],
        'tn id': '',
        'oscar year': film['oscar year']
    }
    for film in imdb
    if film.get('oscar year') in [1962, 1963, 1964]
]

# Prepend to tn
tn = extra_movies + tn

# %%
for film in tn:
    if film['tn id'] == '':
        film['tn id'] = format_title(film['title'], style='tn', sep='-')

# %%
for film in tn:
    tn_id = film['tn id']

    url = f'https://www.the-numbers.com/movie/{tn_id}#tab=summary'
    domestic, international, worldwide, genre, studio, country, runtime, release_year = get_tn(url, headers)

    film['domestic'] = domestic
    film['international'] = international
    film['worldwide'] = worldwide
    film['genre'] = genre
    film['studio'] = studio
    film['country'] = country
    film['runtime'] = runtime
    film['release year'] = release_year

# %%
for film in tn:
    if film.get('title') == 'Lilies of the Field':
        film['tn id'] = 'Lilies-of-the-Field-(1963)'

        url = f"https://www.the-numbers.com/movie/{film['tn id']}#tab=summary"

        domestic, international, worldwide, genre, studio, country, runtime, release_year = get_tn(url, headers)

        film['domestic'] = domestic
        film['international'] = international
        film['worldwide'] = worldwide
        film['genre'] = genre
        film['studio'] = studio
        film['country'] = country
        film['runtime'] = runtime
        film['release year'] = release_year

# %% [markdown]
# # V. Final Dataset

# %%
imdb_df = pd.DataFrame(imdb).drop(columns=['imdb id'])
meta_df = pd.DataFrame(meta).drop(columns=['title', 'release year', 'meta id'])
rt_df = pd.DataFrame(rt).drop(columns=['title', 'release year', 'rt id'])
tn_df = pd.DataFrame(tn).drop(columns=['tn id'])

# concat
df = pd.concat([imdb_df, meta_df, rt_df], axis=1)

# %%
df['match_title'] = ''
df['match_score'] = ''

# Perform matching within each Oscar year
for year in df['oscar year'].unique():
    df_year = df[df['oscar year'] == year]
    tn_year = tn_df[tn_df['oscar year'] == year]
    
    if tn_year.empty:
        continue

    matches = df_year['title'].apply(
        lambda x: process.extractOne(x, tn_year['title'], scorer=fuzz.token_sort_ratio)
    )
    
    df.loc[df_year.index, 'match_title'] = matches.apply(lambda x: x[0] if x else '')
    df.loc[df_year.index, 'match_score'] = matches.apply(lambda x: x[1] if x else '')

# %%
df[df['match_score'] <= 50]
# Out:
#      oscar year  \
# 17         1965
# 58         1973
# 62         1974
# 173        1996
# 187        1999
# 246        2010
# 350        2022
# 353        2022
# 361        2023
# 371        2024
# 385        2025
#
#                                                                     title  \
# 17   Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb
# 58                                                          The Emigrants
# 62                                                       Cries & Whispers
# 173                                                           The Postman
# 187                                                     Life Is Beautiful
# 246                                                              Precious
# 350                                                        Dune: Part One
# 353                                                          Drive My Car
# 361                                                                   Tár
# 371                                                     Anatomy of a Fall
# 385                                                        I'm Still Here
#
#         result release year    rated        budget    language imdb rating  \
# 17   Nominated         1964       PG    $1,800,000     English         8.3
# 58   Nominated         1971       PG                   Swedish           8
# 62   Nominated         1972        R      $400,000     Swedish         7.9
# 173  Nominated         1994       PG    $3,000,000     Italian         7.8
# 187  Nominated         1997    PG-13   $20,000,000     Italian         8.6
# 246  Nominated         2009        R   $10,000,000     English         7.3
# 350  Nominated         2021    PG-13  $165,000,000     English           8
# 353  Nominated         2021  Unrated                  Japanese         7.5
# 361  Nominated         2022        R   $25,000,000     English         7.4
# 371  Nominated         2023        R  EUR6,200,000      French         7.6
# 385  Nominated         2024    PG-13                Portuguese         8.3
#
#     imdb votes metascore meta votes rt score rt votes audience score  \
# 17     537,637        97         32       98       96             94
# 58       7,906                            94       17             87
# 62      38,517                            91       34             90
# 173     40,269        81         13       94       35             94
# 187    778,258        58         32       81       94             96
# 246    118,609        78         36       92      239             77
# 350    956,644        74         68       83      514             90
# 353     72,498        91         42       97      215             78
# 361    103,795        93         59       91      356             74
# 371    175,040        86         44       96      285             91
# 385    107,787        85         43       97      192             97
#
#     audience votes           match_title match_score
# 17        100,000+       Dr. Strangelove   36.144578
# 58            500+         The Godfather   46.153846
# 62          5,000+          The Exorcist   42.857143
# 173        10,000+            Il Postino   47.619048
# 187       100,000+   Shakespeare in Love   27.777778
# 246       100,000+         A Serious Man   47.619048
# 350         5,000+                  Dune   44.444444
# 353         1,000+        Licorice Pizza   30.769231
# 361           250+                   TÁR   33.333333
# 371           100+  Anatomie d'une chute   43.243243
# 385           500+           Nickel Boys        24.0

# %%
fix = {
    'The Emigrants': 'Utvandrarna',
    'Cries & Whispers': 'Viskningar och rop',
    'Life Is Beautiful': 'La vita è bella',
    'Precious': 'Precious (Based on the Nove…',
    'Drive My Car': 'Doraibu mai kâ',
    'I\'m Still Here': 'Ainda Estou Aqui'
}

df['match_title'] = df.apply(
    lambda row: fix.get(row['title'], row['match_title']),
    axis=1
)

# %%
df = df.sort_values(by='match_title', ascending=True).reset_index(drop=True)
tn_df = tn_df.sort_values(by='title', ascending=True).reset_index(drop=True)

df.drop(['match_title', 'match_score'], axis=1, inplace=True)
tn_df.drop(['title', 'oscar year', 'release year'], axis=1, inplace=True)

final = pd.concat([df, tn_df], axis=1)

# %%
final.to_csv('oscar_bp.csv', index=False)
